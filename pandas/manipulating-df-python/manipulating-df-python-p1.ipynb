# %% [markdown]
# # Manipulating DataFrames with Python | Part 1 (Slicing, Filtering and Indexing)
#
# Source code from Medium's article [Manipulating DataFrames with Python | Part 1 (Slicing, Filtering and Indexing)](https://bit.ly/2PztdVY), written by [Ankita Prasad](https://ankita2108prasad.medium.com/).

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Read dataset

# %%
df = pd.read_pickle('./hs_aws_costos')

# %%
df
# Out:
#                        UsageType            Service      Cost CostUnit  \
# 0           USE1-CostDataStorage  AWS Cost Explorer  0.015232      USD
# 1           USE1-CostDataStorage  AWS Cost Explorer  0.015740      USD
# 2           USE1-CostDataStorage  AWS Cost Explorer  0.015848      USD
# 3           USE1-CostDataStorage  AWS Cost Explorer  0.016307      USD
# 4           USE1-CostDataStorage  AWS Cost Explorer  0.016076      USD
# ...                          ...                ...       ...      ...
# 19580  USW2-TimedStorage-ByteHrs                Tax  0.000000      USD
# 19581    USW2-USE1-AWS-Out-Bytes                Tax  0.000000      USD
# 19582    USW2-USW1-AWS-Out-Bytes                Tax  0.000000      USD
# 19583        USW2-UnusedStaticIP                Tax  0.000000      USD
# 19584     us-west-2-KMS-Requests                Tax  0.000000      USD
#
#       PeriodStart  PeriodEnd Total Estimated                  CreatedAt
# 0      2020-12-01 2020-12-02    {}     False 2021-03-24 05:11:08.261684
# 1      2020-12-02 2020-12-03    {}     False 2021-03-24 05:11:08.261684
# 2      2020-12-03 2020-12-04    {}     False 2021-03-24 05:11:08.261684
# 3      2020-12-04 2020-12-05    {}     False 2021-03-24 05:11:08.261684
# 4      2020-12-05 2020-12-06    {}     False 2021-03-24 05:11:08.261684
# ...           ...        ...   ...       ...                        ...
# 19580  2021-03-01 2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 19581  2021-03-01 2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 19582  2021-03-01 2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 19583  2021-03-01 2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 19584  2021-03-01 2021-03-02    {}      True 2021-03-24 05:11:13.860169
#
# [19585 rows x 9 columns]

# %% [markdown]
# ## Slicing DataFrames

# %%
# Returns series of "col_name" of x to y row index -> part of #col_name from x to y-1 index
#
df['Service'][0:4]
# Out:
# 0    AWS Cost Explorer
# 1    AWS Cost Explorer
# 2    AWS Cost Explorer
# 3    AWS Cost Explorer
# Name: Service, dtype: object

# %%
df1 = df.set_index('PeriodStart')
df1
# Out:
#                              UsageType            Service      Cost CostUnit  \
# PeriodStart
# 2020-12-01        USE1-CostDataStorage  AWS Cost Explorer  0.015232      USD
# 2020-12-02        USE1-CostDataStorage  AWS Cost Explorer  0.015740      USD
# 2020-12-03        USE1-CostDataStorage  AWS Cost Explorer  0.015848      USD
# 2020-12-04        USE1-CostDataStorage  AWS Cost Explorer  0.016307      USD
# 2020-12-05        USE1-CostDataStorage  AWS Cost Explorer  0.016076      USD
# ...                                ...                ...       ...      ...
# 2021-03-01   USW2-TimedStorage-ByteHrs                Tax  0.000000      USD
# 2021-03-01     USW2-USE1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-01     USW2-USW1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-01         USW2-UnusedStaticIP                Tax  0.000000      USD
# 2021-03-01      us-west-2-KMS-Requests                Tax  0.000000      USD
#
#              PeriodEnd Total Estimated                  CreatedAt
# PeriodStart
# 2020-12-01  2020-12-02    {}     False 2021-03-24 05:11:08.261684
# 2020-12-02  2020-12-03    {}     False 2021-03-24 05:11:08.261684
# 2020-12-03  2020-12-04    {}     False 2021-03-24 05:11:08.261684
# 2020-12-04  2020-12-05    {}     False 2021-03-24 05:11:08.261684
# 2020-12-05  2020-12-06    {}     False 2021-03-24 05:11:08.261684
# ...                ...   ...       ...                        ...
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
#
# [19585 rows x 8 columns]

# %%
# Slicing using loc -> here row_indexes are labels.
# Returns series of data containing rows and columns sequentially
# from col1 to coln and row1 to rown.
#
df1.loc['2020-12-01':'2020-12-02', 'Service': 'Cost']
# Out:
#                                 Service      Cost
# PeriodStart
# 2020-12-01            AWS Cost Explorer  0.015232
# 2020-12-02            AWS Cost Explorer  0.015740
# 2020-12-01       AWS Global Accelerator  0.600000
# 2020-12-02       AWS Global Accelerator  0.600000
# 2020-12-01   AWS Key Management Service  0.000000
# ...                                 ...       ...
# 2020-12-01                          Tax  0.000000
# 2020-12-01                          Tax  0.000000
# 2020-12-01                          Tax  0.000000
# 2020-12-01                          Tax  0.000000
# 2020-12-01                          Tax  0.000000
#
# [416 rows x 2 columns]

# %%
# Returns the value from row col pair in dataframe.
#
df1.loc['2020-12-24', 'Cost']
# Out:
# PeriodStart
# 2020-12-24    0.015915
# 2020-12-24    0.600000
# 2020-12-24    0.006453
# 2020-12-24    0.000000
# 2020-12-24    0.000980
#                 ...
# 2020-12-24    0.000000
# 2020-12-24    0.000000
# 2020-12-24    0.532258
# 2020-12-24    0.000000
# 2020-12-24    0.000000
# Name: Cost, Length: 178, dtype: float32

# %%
# Slicing using iloc -> here row indexes are numbers.
# Returns the series of data from row_num_start to row_num_end-1
#
df1.iloc[[0, 9]]
# Out:
#                         UsageType            Service      Cost CostUnit  \
# PeriodStart
# 2020-12-01   USE1-CostDataStorage  AWS Cost Explorer  0.015232      USD
# 2020-12-10   USE1-CostDataStorage  AWS Cost Explorer  0.016213      USD
#
#              PeriodEnd Total Estimated                  CreatedAt
# PeriodStart
# 2020-12-01  2020-12-02    {}     False 2021-03-24 05:11:08.261684
# 2020-12-10  2020-12-11    {}     False 2021-03-24 05:11:08.261684

# %%
# Returns the dataframe from row_num_start to row_num_end-1 and 
# from col_num_start to col_num_end-1.
#
df1.iloc[[0, 9], [1, 2]]
# Out:
#                        Service      Cost
# PeriodStart
# 2020-12-01   AWS Cost Explorer  0.015232
# 2020-12-10   AWS Cost Explorer  0.016213

# %%
# Returns the value from the row col pair in dataframe
#
df1.iloc[0, 0]
# Out:
# 'USE1-CostDataStorage'

# %% [markdown]
# ## Filtering DataFrames

# %%
# Creating boolean series.
# df.Cost > 10 is the filter for selecting only the rows which have value
# greater than 10, filters can also be combined using |, & and ! operators.
#
df1.loc[df1.Cost > 60]
# Out:
#                               UsageType  \
# PeriodStart
# 2020-12-01   USW2-HeavyUsage:r5a.xlarge
# 2021-01-01   USW2-HeavyUsage:r5a.xlarge
# 2021-02-01   USW2-HeavyUsage:r5a.xlarge
# 2021-03-01   USW2-HeavyUsage:r5a.xlarge
#
#                                             Service        Cost CostUnit  \
# PeriodStart
# 2020-12-01   Amazon Elastic Compute Cloud - Compute  727.632019      USD
# 2021-01-01   Amazon Elastic Compute Cloud - Compute  727.632019      USD
# 2021-02-01   Amazon Elastic Compute Cloud - Compute  657.216003      USD
# 2021-03-01   Amazon Elastic Compute Cloud - Compute  727.632019      USD
#
#              PeriodEnd Total Estimated                  CreatedAt
# PeriodStart
# 2020-12-01  2020-12-02    {}     False 2021-03-24 05:11:11.372433
# 2021-01-01  2021-01-02    {}     False 2021-03-24 05:11:11.372433
# 2021-02-01  2021-02-02    {}     False 2021-03-24 05:11:11.372433
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:11.372433

# %%
# Selecting columns with all non-zeros
#
df1.loc[:, df1.all()]
# Out:
#                              UsageType            Service CostUnit  PeriodEnd  \
# PeriodStart
# 2020-12-01        USE1-CostDataStorage  AWS Cost Explorer      USD 2020-12-02
# 2020-12-02        USE1-CostDataStorage  AWS Cost Explorer      USD 2020-12-03
# 2020-12-03        USE1-CostDataStorage  AWS Cost Explorer      USD 2020-12-04
# 2020-12-04        USE1-CostDataStorage  AWS Cost Explorer      USD 2020-12-05
# 2020-12-05        USE1-CostDataStorage  AWS Cost Explorer      USD 2020-12-06
# ...                                ...                ...      ...        ...
# 2021-03-01   USW2-TimedStorage-ByteHrs                Tax      USD 2021-03-02
# 2021-03-01     USW2-USE1-AWS-Out-Bytes                Tax      USD 2021-03-02
# 2021-03-01     USW2-USW1-AWS-Out-Bytes                Tax      USD 2021-03-02
# 2021-03-01         USW2-UnusedStaticIP                Tax      USD 2021-03-02
# 2021-03-01      us-west-2-KMS-Requests                Tax      USD 2021-03-02
#
#                              CreatedAt
# PeriodStart
# 2020-12-01  2021-03-24 05:11:08.261684
# 2020-12-02  2021-03-24 05:11:08.261684
# 2020-12-03  2021-03-24 05:11:08.261684
# 2020-12-04  2021-03-24 05:11:08.261684
# 2020-12-05  2021-03-24 05:11:08.261684
# ...                                ...
# 2021-03-01  2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-24 05:11:13.860169
#
# [19585 rows x 5 columns]

# %%
# Selecting columns with any non-zeros
#
df1.loc[:, df1.any()]
# Out:
#                              UsageType            Service      Cost CostUnit  \
# PeriodStart
# 2020-12-01        USE1-CostDataStorage  AWS Cost Explorer  0.015232      USD
# 2020-12-02        USE1-CostDataStorage  AWS Cost Explorer  0.015740      USD
# 2020-12-03        USE1-CostDataStorage  AWS Cost Explorer  0.015848      USD
# 2020-12-04        USE1-CostDataStorage  AWS Cost Explorer  0.016307      USD
# 2020-12-05        USE1-CostDataStorage  AWS Cost Explorer  0.016076      USD
# ...                                ...                ...       ...      ...
# 2021-03-01   USW2-TimedStorage-ByteHrs                Tax  0.000000      USD
# 2021-03-01     USW2-USE1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-01     USW2-USW1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-
#
# [19585 rows x 0 columns]

# %%
# Dropping rows with any NaNs.
#
df2 = df1.dropna(how = 'any')
df2
# Out:
#                              UsageType            Service      Cost CostUnit  \
# PeriodStart
# 2020-12-01        USE1-CostDataStorage  AWS Cost Explorer  0.015232      USD
# 2020-12-02        USE1-CostDataStorage  AWS Cost Explorer  0.015740      USD
# 2020-12-03        USE1-CostDataStorage  AWS Cost Explorer  0.015848      USD
# 2020-12-04        USE1-CostDataStorage  AWS Cost Explorer  0.016307      USD
# 2020-12-05        USE1-CostDataStorage  AWS Cost Explorer  0.016076      USD
# ...                                ...                ...       ...      ...
# 2021-03-01   USW2-TimedStorage-ByteHrs                Tax  0.000000      USD
# 2021-03-01     USW2-USE1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-01     USW2-USW1-AWS-Out-Bytes                Tax  0.000000      USD
# 2021-03-01         USW2-UnusedStaticIP                Tax  0.000000      USD
# 2021-03-01      us-west-2-KMS-Requests                Tax  0.000000      USD
#
#              PeriodEnd Total Estimated                  CreatedAt
# PeriodStart
# 2020-12-01  2020-12-02    {}     False 2021-03-24 05:11:08.261684
# 2020-12-02  2020-12-03    {}     False 2021-03-24 05:11:08.261684
# 2020-12-03  2020-12-04    {}     False 2021-03-24 05:11:08.261684
# 2020-12-04  2020-12-05    {}     False 2021-03-24 05:11:08.261684
# 2020-12-05  2020-12-06    {}     False 2021-03-24 05:11:08.261684
# ...                ...   ...       ...                        ...
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
# 2021-03-01  2021-03-02    {}      True 2021-03-24 05:11:13.860169
#
# [19585 rows x 8 columns]

# %%
# Filtering a column based on another .
#
# df.eggs[df.salt > 55]

# %%
# Modyfying a column based on another.
#
# df.eggs[df.salt > 55] += 5

# %%
# Convert to dozens(12) unit
#
# df.floordiv(12)
# df.apply(lambda x: x//12)

# %% [markdown]
# ## Index Objects and Labeled Data

# %% [markdown]
# ### 1. Creating a Series v/s Creating an Index

# %%
prices = [10.70, 10.86, 10.74, 8.48]
shares = pd.Series(prices)
print(shares)
# Out:
# 0    10.70
# 1    10.86
# 2    10.74
# 3     8.48
# dtype: float64

# %%
days = ['Mon', 'Tue', 'Wed', 'Thur']
prices = [10.70, 10.86, 10.74, 8.48]

shares = pd.Series(prices, index=days)

print(shares)
# Out:
# Mon     10.70
# Tue     10.86
# Wed     10.74
# Thur     8.48
# dtype: float64

# %% [markdown]
# ### 2. Modifying Index Values

# %%
# Deliberately introduced error.
#
shares.index[2] = 'Wednesday'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Users\jpied\anaconda3\envs\python-data\lib\site-packages\IPython\core\interactiveshell.py, in run_code:
# Line 3437:  exec(code_obj, self.user_global_ns, self.user_ns)
#
# In  [23]:
# Line 1:     shares.index[2] = 'Wednesday'
#
# File C:\Users\jpied\anaconda3\envs\python-data\lib\site-packages\pandas\core\indexes\base.py, in __setitem__:
# Line 4277:  raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations
# ---------------------------------------------------------------------------

# %%
# Right way -> overriding all at once.

shares.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday']
print(shares)
# Out:
# Monday       10.70
# Tuesday      10.86
# Wednesday    10.74
# Thursday      8.48
# dtype: float64

# %%
#Assigning Index Values
#
# unemployment.index = unemployment['zip'] #where zip is a column in unemployment

# %% [markdown]
# ### 3. Hierarchical Indexing (Multi-indexing)

# %%
df2 = df.set_index(['PeriodStart', 'Service'])
df2
# Out:
#                                                UsageType      Cost CostUnit  \
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer       USE1-CostDataStorage  0.015232      USD
# 2020-12-02  AWS Cost Explorer       USE1-CostDataStorage  0.015740      USD
# 2020-12-03  AWS Cost Explorer       USE1-CostDataStorage  0.015848      USD
# 2020-12-04  AWS Cost Explorer       USE1-CostDataStorage  0.016307      USD
# 2020-12-05  AWS Cost Explorer       USE1-CostDataStorage  0.016076      USD
# ...                                                  ...       ...      ...
# 2021-03-01  Tax                USW2-TimedStorage-ByteHrs  0.000000      USD
#             Tax                  USW2-USE1-AWS-Out-Bytes  0.000000      USD
#             Tax                  USW2-USW1-AWS-Out-Bytes  0.000000      USD
#             Tax                      USW2-UnusedStaticIP  0.000000      USD
#             Tax                   us-west-2-KMS-Requests  0.000000      USD
#
#                                PeriodEnd Total Estimated  \
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer 2020-12-02    {}     False
# 2020-12-02  AWS Cost Explorer 2020-12-03    {}     False
# 2020-12-03  AWS Cost Explorer 2020-12-04    {}     False
# 2020-12-04  AWS Cost Explorer 2020-12-05    {}     False
# 2020-12-05  AWS Cost Explorer 2020-12-06    {}     False
# ...                                  ...   ...       ...
# 2021-03-01  Tax               2021-03-02    {}      True
#             Tax               2021-03-02    {}      True
#             Tax               2021-03-02    {}      True
#             Tax               2021-03-02    {}      True
#             Tax               2021-03-02    {}      True
#
#                                                CreatedAt
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer 2021-03-24 05:11:08.261684
# 2020-12-02  AWS Cost Explorer 2021-03-24 05:11:08.261684
# 2020-12-03  AWS Cost Explorer 2021-03-24 05:11:08.261684
# 2020-12-04  AWS Cost Explorer 2021-03-24 05:11:08.261684
# 2020-12-05  AWS Cost Explorer 2021-03-24 05:11:08.261684
# ...                                                  ...
# 2021-03-01  Tax               2021-03-24 05:11:13.860169
#             Tax               2021-03-24 05:11:13.860169
#             Tax               2021-03-24 05:11:13.860169
#             Tax               2021-03-24 05:11:13.860169
#             Tax               2021-03-24 05:11:13.860169
#
# [19585 rows x 7 columns]

# %% [markdown]
# ### Fancy Indexing

# %% [markdown]
# #### Outermost Indexing

# %%
df2.loc[(['2020-12-24', '2020-12-31'], 'AWS Global Accelerator'), :]
# Out:
#                                                        UsageType  Cost  \
# PeriodStart Service
# 2020-12-24  AWS Global Accelerator  Global-Accelerator-fixed-fee   0.6
# 2020-12-31  AWS Global Accelerator  Global-Accelerator-fixed-fee   0.5
#
#                                    CostUnit  PeriodEnd Total Estimated  \
# PeriodStart Service
# 2020-12-24  AWS Global Accelerator      USD 2020-12-25    {}     False
# 2020-12-31  AWS Global Accelerator      USD 2021-01-01    {}     False
#
#                                                     CreatedAt
# PeriodStart Service
# 2020-12-24  AWS Global Accelerator 2021-03-24 05:11:08.477572
# 2020-12-31  AWS Global Accelerator 2021-03-24 05:11:08.477572

# %% [markdown]
# #### Innermost Indexing

# %%
df2.sort_index(inplace=True)
df2.loc[('2020-12-31', ['AWS Global Accelerator', 'AWS Cost Explorer']), 'Cost']
# Out:
# PeriodStart  Service
# 2020-12-31   AWS Cost Explorer         0.016524
#              AWS Global Accelerator    0.500000
# Name: Cost, dtype: float32

# %% [markdown]
# ### 5. Sorting Indexes

# %%
df2 = df2.sort_index()
df2
# Out:
#                                                            UsageType  \
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer                   USE1-CostDataStorage
#             AWS Global Accelerator      Global-Accelerator-fixed-fee
#             AWS Key Management Service        us-west-1-KMS-Requests
#             AWS Lambda                    USW1-DataTransfer-In-Bytes
#             AWS Lambda                   USW1-DataTransfer-Out-Bytes
# ...                                                              ...
# 2021-03-21  EC2 - Other                      USW2-USE1-AWS-Out-Bytes
#             EC2 - Other                       USW2-USE2-AWS-In-Bytes
#             EC2 - Other                      USW2-USE2-AWS-Out-Bytes
#             EC2 - Other                       USW2-USW1-AWS-In-Bytes
#             EC2 - Other                      USW2-USW1-AWS-Out-Bytes
#
#                                                 Cost CostUnit  PeriodEnd  \
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer           1.523226e-02      USD 2020-12-02
#             AWS Global Accelerator      6.000000e-01      USD 2020-12-02
#             AWS Key Management Service  0.000000e+00      USD 2020-12-02
#             AWS Lambda                  0.000000e+00      USD 2020-12-02
#             AWS Lambda                  0.000000e+00      USD 2020-12-02
# ...                                              ...      ...        ...
# 2021-03-21  EC2 - Other                 1.258390e-05      USD 2021-03-22
#             EC2 - Other                 0.000000e+00      USD 2021-03-22
#             EC2 - Other                 1.738000e-07      USD 2021-03-22
#             EC2 - Other                 0.000000e+00      USD 2021-03-22
#             EC2 - Other                 5.930000e-08      USD 2021-03-22
#
#                                        Total Estimated  \
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer             {}     False
#             AWS Global Accelerator        {}     False
#             AWS Key Management Service    {}     False
#             AWS Lambda                    {}     False
#             AWS Lambda                    {}     False
# ...                                      ...       ...
# 2021-03-21  EC2 - Other                   {}      True
#             EC2 - Other                   {}      True
#             EC2 - Other                   {}      True
#             EC2 - Other                   {}      True
#             EC2 - Other                   {}      True
#
#                                                         CreatedAt
# PeriodStart Service
# 2020-12-01  AWS Cost Explorer          2021-03-24 05:11:08.261684
#             AWS Global Accelerator     2021-03-24 05:11:08.477572
#             AWS Key Management Service 2021-03-24 05:11:08.683079
#             AWS Lambda                 2021-03-24 05:11:08.959199
#             AWS Lambda                 2021-03-24 05:11:08.959199
# ...                                                           ...
# 2021-03-21  EC2 - Other                2021-03-24 05:11:10.048152
#             EC2 - Other                2021-03-24 05:11:10.048152
#             EC2 - Other                2021-03-24 05:11:10.048152
#             EC2 - Other                2021-03-24 05:11:10.048152
#             EC2 - Other                2021-03-24 05:11:10.048152
#
# [19585 rows x 7 columns]
