# %% [markdown]
# # Selecting Rows with .loc
#
# Source code from Medium's article ["Selecting Rows with .loc"](https://towardsdatascience.com/selecting-rows-with-loc-276d217c4ea5) written by [Ednalyn C. De Dios](https://towardsdatascience.com/@ednalyn.dedios).

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd

# to print out all the ouputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Display options

# %%
# Set display options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Functions

# %%
def show_missing(df):
    """
    Return the total missing values and the percentage of
    missing values by column.
    """
    null_count = df.isnull().sum()
    null_percentage = (null_count / df.shape[0]) * 100
    
    empty_count = pd.Series(((df == " ") | (df == "")).sum())
    empty_percentage = (empty_count / df.shape[0]) * 100
    
    nan_count = pd.Series(((df == "nan") | (df == "NaN")).sum())
    nan_percentage = (nan_count / df.shape[0]) * 100
    
    return pd.DataFrame({"num_missing": null_count, "missing_percentage": null_percentage,
                              "num_empty": empty_count, "empty_percentage": empty_percentage,
                              "nan_count": nan_count, "nan_percentage": nan_percentage})

# %% [markdown]
# # Getting the Data

# %%
df = pd.read_csv("./allservicecalls.csv")

# %%
df.head()
# Out:
#                    Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0  Streets & Infrastructure  1010126853     12/10/2011  12/11/2011
# 1  Streets & Infrastructure  1010126880     12/10/2011  12/13/2011
# 2               Information  1010338011      5/25/2012         NaN
# 3                  Graffiti  1010444245      8/15/2012   8/30/2012
# 4      Property Maintenance  1010888252       6/6/2013    8/9/2013
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0       3/5/2020           YES   Trans & Cap Improvements
# 1       3/5/2020           YES   Trans & Cap Improvements
# 2      1/27/2020            NO       Knowledge Management
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                                   TYPENAME  \
# 0                Storm Water                                Tree Fallen
# 1                    Streets  Barricade - Misc. Special Event/Emergency
# 2                  Knowledge                   Knowledge Solution Extra
# 3                   Graffiti                   Graffiti Public Property
# 4  Code Enforcement (IntExp)                      Alley-Way Maintenance
#
#   CaseStatus          SourceID                               OBJECTDESC  \
# 0     Closed  Constituent Call                ELM CREEK and WURZBACH RD
# 1     Closed  Constituent Call  1600  CENTENNIAL BV, San Antonio, 78211
# 2     Closed  Constituent Call    310  ROOSEVELT AV, San Antonio, 78210
# 3       Open        Web Portal    600  NOGALITOS ST, San Antonio, 78204
# 4       Open        Web Portal   6043  CASTLE QUEEN, San Antonio, 78218
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 8  2113584.0  13747492.0            9/19/2019
# 1                 5  2116553.0  13684805.0            9/19/2019
# 2                 5  2132295.0  13693603.0            9/19/2019
# 3                 5  2125683.0  13695548.0            9/19/2019
# 4                 2  2169702.0  13725769.0            9/19/2019
#
#   Report Ending Date
# 0          9/19/2020
# 1          9/19/2020
# 2          9/19/2020
# 3          9/19/2020
# 4          9/19/2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543645 entries, 0 to 543644
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Category              543645 non-null  object
#  1   CASEID                543645 non-null  int64
#  2   OPENEDDATETIME        543645 non-null  object
#  3   SLA_Date              533133 non-null  object
#  4   CLOSEDDATETIME        502579 non-null  object
#  5   Late (Yes/No)         543645 non-null  object
#  6   Dept                  482532 non-null  object
#  7   REASONNAME            543645 non-null  object
#  8   TYPENAME              543645 non-null  object
#  9   CaseStatus            543645 non-null  object
#  10  SourceID              543645 non-null  object
#  11  OBJECTDESC            543645 non-null  object
#  12  Council District      543645 non-null  int64
#  13  XCOORD                542921 non-null  float64
#  14  YCOORD                542921 non-null  float64
#  15  Report Starting Date  543645 non-null  object
#  16  Report Ending Date    543645 non-null  object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 70.5+ MB

# %%
show_missing(df)
# Out:
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# C:\Users\jpied\.conda\envs\jpnb_py38\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
#                       num_missing  missing_percentage  num_empty  \
# Category                        0            0.000000          0
# CASEID                          0            0.000000          0
# OPENEDDATETIME                  0            0.000000          0
# SLA_Date                    10512            1.933615          0
# CLOSEDDATETIME              41066            7.553826          0
# Late (Yes/No)                   0            0.000000          0
# Dept                        61113           11.241343          0
# REASONNAME                      0            0.000000          0
# TYPENAME                        0            0.000000          0
# CaseStatus                      0            0.000000          0
# SourceID                        0            0.000000          0
# OBJECTDESC                      0            0.000000        720
# Council District                0            0.000000          0
# XCOORD                        724            0.133175          0
# YCOORD                        724            0.133175          0
# Report Starting Date            0            0.000000          0
# Report Ending Date              0            0.000000          0
#
#                       empty_percentage  nan_count  nan_percentage
# Category                      0.000000          0             0.0
# CASEID                        0.000000          0             0.0
# OPENEDDATETIME                0.000000          0             0.0
# SLA_Date                      0.000000          0             0.0
# CLOSEDDATETIME                0.000000          0             0.0
# Late (Yes/No)                 0.000000          0             0.0
# Dept                          0.000000          0             0.0
# REASONNAME                    0.000000          0             0.0
# TYPENAME                      0.000000          0             0.0
# CaseStatus                    0.000000          0             0.0
# SourceID                      0.000000          0             0.0
# OBJECTDESC                    0.132439          0             0.0
# Council District              0.000000          0             0.0
# XCOORD                        0.000000          0             0.0
# YCOORD                        0.000000          0             0.0
# Report Starting Date          0.000000          0             0.0
# Report Ending Date            0.000000          0             0.0

# %% [markdown]
# # Selecting rows where the column is null or not

# %%
df["Dept"].value_counts(dropna=False)

df_null = df.loc[df["Dept"].isnull()]
df_null.head()
df_null.shape

df_notnull = df.loc[df["Dept"].notnull()]
df_notnull.head()
df_notnull.shape
# Out:
# Solid Waste Management       199828
# Development Services         117935
# Animal Care Services          73471
# NaN                           61113
# Code Enforcement Services     59730
# Trans & Cap Improvements      18049
# Customer Service               7286
# Metro Health                   3164
# Parks and Recreation           3015
# City Council                     53
# Knowledge Management              1
# Name: Dept, dtype: int64
#                   Category      CASEID OPENEDDATETIME   SLA_Date  \
# 3435  Property Maintenance  1014315871      3/12/2018  3/26/2018
# 7894  Property Maintenance  1015243237      1/31/2019  2/14/2019
# 7916  Property Maintenance  1015244677      1/31/2019  2/14/2019
# 7917  Property Maintenance  1015244698      1/31/2019  2/14/2019
# 8237  Property Maintenance  1015265305       2/8/2019  2/22/2019
#
#      CLOSEDDATETIME Late (Yes/No) Dept                   REASONNAME  \
# 3435            NaN           YES  NaN  Code Enforcement (Internal)
# 7894       6/6/2020           YES  NaN  Code Enforcement (Internal)
# 7916       6/6/2020           YES  NaN  Code Enforcement (Internal)
# 7917            NaN           YES  NaN  Code Enforcement (Internal)
# 8237            NaN           YES  NaN  Code Enforcement (Internal)
#
#                   TYPENAME CaseStatus                    SourceID  \
# 3435  Zoning: Recycle Yard       Open  Internal Services Requests
# 7894  Zoning: Recycle Yard     Closed  Internal Services Requests
# 7916  Zoning: Recycle Yard     Closed  Internal Services Requests
# 7917  Zoning: Recycle Yard       Open  Internal Services Requests
# 8237  Zoning: Recycle Yard       Open  Internal Services Requests
#
#                                     OBJECTDESC  Council District     XCOORD  \
# 3435  9655  NEW LAREDO HWY, San Antonio, 78211                 4  2096027.0
# 7894     1532  SOMERSET RD, San Antonio, 78211                 4  2113308.0
# 7916      819  SOMERSET RD, San Antonio, 78211                 5  2114674.0
# 7917      925  SOMERSET RD, San Antonio, 78211                 5  2114464.0
# 8237    2300  FRIO CITY RD, San Antonio, 78226                 5  2113348.0
#
#           YCOORD Report Starting Date Report Ending Date
# 3435  13665977.0            9/19/2019          9/19/2020
# 7894  13679060.0            9/19/2019          9/19/2020
# 7916  13681387.0            9/19/2019          9/19/2020
# 7917  13681208.0            9/19/2019          9/19/2020
# 8237  13688941.0            9/19/2019          9/19/2020
# (61113, 17)
#                    Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0  Streets & Infrastructure  1010126853     12/10/2011  12/11/2011
# 1  Streets & Infrastructure  1010126880     12/10/2011  12/13/2011
# 2               Information  1010338011      5/25/2012         NaN
# 3                  Graffiti  1010444245      8/15/2012   8/30/2012
# 4      Property Maintenance  1010888252       6/6/2013    8/9/2013
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0       3/5/2020           YES   Trans & Cap Improvements
# 1       3/5/2020           YES   Trans & Cap Improvements
# 2      1/27/2020            NO       Knowledge Management
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                                   TYPENAME  \
# 0                Storm Water                                Tree Fallen
# 1                    Streets  Barricade - Misc. Special Event/Emergency
# 2                  Knowledge                   Knowledge Solution Extra
# 3                   Graffiti                   Graffiti Public Property
# 4  Code Enforcement (IntExp)                      Alley-Way Maintenance
#
#   CaseStatus          SourceID                               OBJECTDESC  \
# 0     Closed  Constituent Call                ELM CREEK and WURZBACH RD
# 1     Closed  Constituent Call  1600  CENTENNIAL BV, San Antonio, 78211
# 2     Closed  Constituent Call    310  ROOSEVELT AV, San Antonio, 78210
# 3       Open        Web Portal    600  NOGALITOS ST, San Antonio, 78204
# 4       Open        Web Portal   6043  CASTLE QUEEN, San Antonio, 78218
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 8  2113584.0  13747492.0            9/19/2019
# 1                 5  2116553.0  13684805.0            9/19/2019
# 2                 5  2132295.0  13693603.0            9/19/2019
# 3                 5  2125683.0  13695548.0            9/19/2019
# 4                 2  2169702.0  13725769.0            9/19/2019
#
#   Report Ending Date
# 0          9/19/2020
# 1          9/19/2020
# 2          9/19/2020
# 3          9/19/2020
# 4          9/19/2020
# (482532, 17)

# %% [markdown]
# # Selecting rows where the column is a specific value

# %%
df["Late (Yes/No)"].value_counts(dropna=False)

df_late = df.loc[df["Late (Yes/No)"] == "YES"]
df_late.head()
df_late.shape

df_notlate = df.loc[df["Late (Yes/No)"] == "NO"]
df_notlate.head()
df_notlate.shape
# Out:
# NO     462606
# YES     81039
# Name: Late (Yes/No), dtype: int64
#                    Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0  Streets & Infrastructure  1010126853     12/10/2011  12/11/2011
# 1  Streets & Infrastructure  1010126880     12/10/2011  12/13/2011
# 3                  Graffiti  1010444245      8/15/2012   8/30/2012
# 4      Property Maintenance  1010888252       6/6/2013    8/9/2013
# 5      Property Maintenance  1010966128      7/19/2013   9/23/2013
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0       3/5/2020           YES   Trans & Cap Improvements
# 1       3/5/2020           YES   Trans & Cap Improvements
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
# 5            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                                   TYPENAME  \
# 0                Storm Water                                Tree Fallen
# 1                    Streets  Barricade - Misc. Special Event/Emergency
# 3                   Graffiti                   Graffiti Public Property
# 4  Code Enforcement (IntExp)                      Alley-Way Maintenance
# 5  Code Enforcement (IntExp)           Junk Vehicle On Private Property
#
#   CaseStatus          SourceID                               OBJECTDESC  \
# 0     Closed  Constituent Call                ELM CREEK and WURZBACH RD
# 1     Closed  Constituent Call  1600  CENTENNIAL BV, San Antonio, 78211
# 3       Open        Web Portal    600  NOGALITOS ST, San Antonio, 78204
# 4       Open        Web Portal   6043  CASTLE QUEEN, San Antonio, 78218
# 5       Open        Web Portal         842  KIRK PL, San Antonio, 78226
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 8  2113584.0  13747492.0            9/19/2019
# 1                 5  2116553.0  13684805.0            9/19/2019
# 3                 5  2125683.0  13695548.0            9/19/2019
# 4                 2  2169702.0  13725769.0            9/19/2019
# 5                 5  2116192.0  13692260.0            9/19/2019
#
#   Report Ending Date
# 0          9/19/2020
# 1          9/19/2020
# 3          9/19/2020
# 4          9/19/2020
# 5          9/19/2020
# (81039, 17)
#                       Category      CASEID OPENEDDATETIME   SLA_Date  \
# 2                  Information  1010338011      5/25/2012        NaN
# 1267  Streets & Infrastructure  1012676462      3/25/2016  11/5/2020
# 2309               Information  1013762220       8/1/2017        NaN
# 2346               Information  1013810864      8/21/2017        NaN
# 2357               Information  1013817308      8/23/2017        NaN
#
#      CLOSEDDATETIME Late (Yes/No)                  Dept            REASONNAME  \
# 2         1/27/2020            NO  Knowledge Management             Knowledge
# 1267            NaN            NO  Development Services  Engineering Division
# 2309      2/26/2020            NO          City Council            District 6
# 2346      2/26/2020            NO          City Council            District 9
# 2357      2/26/2020            NO          City Council           District 10
#
#                                     TYPENAME CaseStatus          SourceID  \
# 2                   Knowledge Solution Extra     Closed  Constituent Call
# 1267       Street Light Existing Res Sub Div       Open  Constituent Call
# 2309        Request for Research/Information     Closed  Constituent Call
# 2346        Request for Research/Information     Closed  Constituent Call
# 2357  CCO_Request for Research/Information_1     Closed  Constituent Call
#
#                                    OBJECTDESC  Council District     XCOORD  \
# 2       310  ROOSEVELT AV, San Antonio, 78210                 5  2132295.0
# 1267     1136  KAYTON AVE, San Antonio, 78210                 3  2143337.0
# 2309              CULEBRA RD and VILLAGE PKWY                 6  2079083.0
# 2346  1323  BLUE CREST LN, San Antonio, 78232                 9  2135747.0
# 2357               AUTRY POND and BULVERDE RD                10  2151822.0
#
#           YCOORD Report Starting Date Report Ending Date
# 2     13693603.0            9/19/2019          9/19/2020
# 1267  13692343.0            9/19/2019          9/19/2020
# 2309  13719525.0            9/19/2019          9/19/2020
# 2346  13752110.0            9/19/2019          9/19/2020
# 2357  13764486.0            9/19/2019          9/19/2020
# (462606, 17)

# %%
df_late
# Out:
# Empty DataFrame
# Columns: [Category, CASEID, OPENEDDATETIME, SLA_Date, CLOSEDDATETIME, Late (Yes/No), Dept, REASONNAME, TYPENAME, CaseStatus, SourceID, OBJECTDESC, Council District, XCOORD, YCOORD, Report Starting Date, Report Ending Date]
# Index: []

# %% [markdown]
# # Selecting rows where the column is not a specific value

# %%
df.Category.value_counts(dropna=False)

df_categorized = df.loc[df["Category"] != "No Category"]
df_categorized.head()
df_categorized.shape
# Out:
# No Category                  334923
# Solid Waste Services          92316
# Property Maintenance          54989
# Animals                       23778
# Streets & Infrastructure      10739
# Traffic Signals and Signs      8524
# Graffiti                       5972
# Information                    4469
# Scooters                       3606
# Parks                          3135
# Health & Sanitation            1184
# Historic Preservation            10
# Name: Category, dtype: int64
#                    Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0  Streets & Infrastructure  1010126853     12/10/2011  12/11/2011
# 1  Streets & Infrastructure  1010126880     12/10/2011  12/13/2011
# 2               Information  1010338011      5/25/2012         NaN
# 3                  Graffiti  1010444245      8/15/2012   8/30/2012
# 4      Property Maintenance  1010888252       6/6/2013    8/9/2013
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 0       3/5/2020           YES   Trans & Cap Improvements
# 1       3/5/2020           YES   Trans & Cap Improvements
# 2      1/27/2020            NO       Knowledge Management
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                                   TYPENAME  \
# 0                Storm Water                                Tree Fallen
# 1                    Streets  Barricade - Misc. Special Event/Emergency
# 2                  Knowledge                   Knowledge Solution Extra
# 3                   Graffiti                   Graffiti Public Property
# 4  Code Enforcement (IntExp)                      Alley-Way Maintenance
#
#   CaseStatus          SourceID                               OBJECTDESC  \
# 0     Closed  Constituent Call                ELM CREEK and WURZBACH RD
# 1     Closed  Constituent Call  1600  CENTENNIAL BV, San Antonio, 78211
# 2     Closed  Constituent Call    310  ROOSEVELT AV, San Antonio, 78210
# 3       Open        Web Portal    600  NOGALITOS ST, San Antonio, 78204
# 4       Open        Web Portal   6043  CASTLE QUEEN, San Antonio, 78218
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 0                 8  2113584.0  13747492.0            9/19/2019
# 1                 5  2116553.0  13684805.0            9/19/2019
# 2                 5  2132295.0  13693603.0            9/19/2019
# 3                 5  2125683.0  13695548.0            9/19/2019
# 4                 2  2169702.0  13725769.0            9/19/2019
#
#   Report Ending Date
# 0          9/19/2020
# 1          9/19/2020
# 2          9/19/2020
# 3          9/19/2020
# 4          9/19/2020
# (208722, 17)

# %%
df_categorized["Category"].value_counts(dropna=False)
# Out:
# Solid Waste Services         92316
# Property Maintenance         54989
# Animals                      23778
# Streets & Infrastructure     10739
# Traffic Signals and Signs     8524
# Graffiti                      5972
# Information                   4469
# Scooters                      3606
# Parks                         3135
# Health & Sanitation           1184
# Historic Preservation           10
# Name: Category, dtype: int64

# %% [markdown]
# # Select rows based on multiple conditions

# %%
df_late_open = df.loc[(df["Late (Yes/No)"] == "YES") & (df["CaseStatus"] == "Open")]

df_late_open.head()
df_late_open.shape
# Out:
#                Category      CASEID OPENEDDATETIME   SLA_Date CLOSEDDATETIME  \
# 3              Graffiti  1010444245      8/15/2012  8/30/2012            NaN
# 4  Property Maintenance  1010888252       6/6/2013   8/9/2013            NaN
# 5  Property Maintenance  1010966128      7/19/2013  9/23/2013            NaN
# 7  Property Maintenance  1011052825      9/16/2013  9/30/2013            NaN
# 8  Property Maintenance  1011052826      9/16/2013  9/30/2013            NaN
#
#   Late (Yes/No)                       Dept                 REASONNAME  \
# 3           YES  Code Enforcement Services                   Graffiti
# 4           YES  Code Enforcement Services  Code Enforcement (IntExp)
# 5           YES  Code Enforcement Services  Code Enforcement (IntExp)
# 7           YES  Code Enforcement Services           Code Enforcement
# 8           YES  Code Enforcement Services           Code Enforcement
#
#                             TYPENAME CaseStatus                    SourceID  \
# 3           Graffiti Public Property       Open                  Web Portal
# 4              Alley-Way Maintenance       Open                  Web Portal
# 5   Junk Vehicle On Private Property       Open                  Web Portal
# 7  Right Of Way/Sidewalk Obstruction       Open  Internal Services Requests
# 8  Right Of Way/Sidewalk Obstruction       Open  Internal Services Requests
#
#                                OBJECTDESC  Council District     XCOORD  \
# 3   600  NOGALITOS ST, San Antonio, 78204                 5  2125683.0
# 4  6043  CASTLE QUEEN, San Antonio, 78218                 2  2169702.0
# 5        842  KIRK PL, San Antonio, 78226                 5  2116192.0
# 7   54  KENROCK RIDGE, San Antonio, 78254                 7  2082242.0
# 8   74  KENROCK RIDGE, San Antonio, 78254                 7  2082389.0
#
#        YCOORD Report Starting Date Report Ending Date
# 3  13695548.0            9/19/2019          9/19/2020
# 4  13725769.0            9/19/2019          9/19/2020
# 5  13692260.0            9/19/2019          9/19/2020
# 7  13737817.0            9/19/2019          9/19/2020
# 8  13737877.0            9/19/2019          9/19/2020
# (27401, 17)

# %% [markdown]
# # Select rows having a column value that belongs in some list of values

# %%
df["Council District"].value_counts(dropna=False)
# Out:
# 1     77217
# 2     73155
# 5     69584
# 3     67088
# 4     52843
# 6     49561
# 7     47592
# 10    43151
# 8     30081
# 9     29515
# 0      3858
# Name: Council District, dtype: int64

# %%
df_south = df.loc[df["Council District"].isin([2, 3, 4, 5])]
df_south.head()
df_south.shape
# Out:
#                    Category      CASEID OPENEDDATETIME    SLA_Date  \
# 1  Streets & Infrastructure  1010126880     12/10/2011  12/13/2011
# 2               Information  1010338011      5/25/2012         NaN
# 3                  Graffiti  1010444245      8/15/2012   8/30/2012
# 4      Property Maintenance  1010888252       6/6/2013    8/9/2013
# 5      Property Maintenance  1010966128      7/19/2013   9/23/2013
#
#   CLOSEDDATETIME Late (Yes/No)                       Dept  \
# 1       3/5/2020           YES   Trans & Cap Improvements
# 2      1/27/2020            NO       Knowledge Management
# 3            NaN           YES  Code Enforcement Services
# 4            NaN           YES  Code Enforcement Services
# 5            NaN           YES  Code Enforcement Services
#
#                   REASONNAME                                   TYPENAME  \
# 1                    Streets  Barricade - Misc. Special Event/Emergency
# 2                  Knowledge                   Knowledge Solution Extra
# 3                   Graffiti                   Graffiti Public Property
# 4  Code Enforcement (IntExp)                      Alley-Way Maintenance
# 5  Code Enforcement (IntExp)           Junk Vehicle On Private Property
#
#   CaseStatus          SourceID                               OBJECTDESC  \
# 1     Closed  Constituent Call  1600  CENTENNIAL BV, San Antonio, 78211
# 2     Closed  Constituent Call    310  ROOSEVELT AV, San Antonio, 78210
# 3       Open        Web Portal    600  NOGALITOS ST, San Antonio, 78204
# 4       Open        Web Portal   6043  CASTLE QUEEN, San Antonio, 78218
# 5       Open        Web Portal         842  KIRK PL, San Antonio, 78226
#
#    Council District     XCOORD      YCOORD Report Starting Date  \
# 1                 5  2116553.0  13684805.0            9/19/2019
# 2                 5  2132295.0  13693603.0            9/19/2019
# 3                 5  2125683.0  13695548.0            9/19/2019
# 4                 2  2169702.0  13725769.0            9/19/2019
# 5                 5  2116192.0  13692260.0            9/19/2019
#
#   Report Ending Date
# 1          9/19/2020
# 2          9/19/2020
# 3          9/19/2020
# 4          9/19/2020
# 5          9/19/2020
# (262670, 17)
